# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

ride_data_to_load = "saferparks_dataset.csv"

data = pd.read_csv(ride_data_to_load)
data.head()
# Out:
#        ID       Date State Ride or Device              Device type  \
# 0  918972   4-Feb-09    FL      Avalanche       Flying carpet ride
# 1  919123   7-Nov-08    CA      Boomerang  Coaster - miscellaneous
# 2  919095  31-Oct-08    CA       tea cups       Spinning cups/tubs
# 3  919094  28-Oct-08    CA       tea cups       Spinning cups/tubs
# 4  917423  23-Oct-08    CA       carousel                 Carousel
#
#               Manufacturer                          Category   Age  \
# 0  Wisdom Industries, Ltd.           Ejection/fall from ride  17.0
# 1                   Vekoma         Unknown (not enough info)  19.0
# 2                      NaN  Illness or neurological symptoms  51.0
# 3                      NaN  Illness or neurological symptoms  38.0
# 4                   Morgan         Entrapment or pinch-point  33.0
#
#                                 Accident Description  \
# 0  17-yo female was ejected from the ride mid-cyl...
# ...
