# %%
# Import dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pprint import pprint

# %%
csv_file = './Resources/saferparks_dataset.csv'

# %%
saferparks = pd.read_csv(csv_file)
saferparks
# Out:
#            ID         Date State         Ride or Device  \
# 0      918972  04-Feb-2009    FL              Avalanche
# 1      919123  07-Nov-2008    CA              Boomerang
# 2      919095  31-Oct-2008    CA               tea cups
# 3      919094  28-Oct-2008    CA               tea cups
# 4      917423  23-Oct-2008    CA               carousel
# 5      919071  18-Oct-2008    CA        looping coaster
# 6      919075  16-Oct-2008    CA              dark ride
# 7      919125  14-Oct-2008    CA         wooden coaster
# 8      919087  13-Oct-2008    CA       flying elephants
# 9      919130  11-Oct-2008    CA             flume ride
# 10     919070  10-Oct-2008    CA         wooden coaster
# 11     919194  04-Oct-2008    CA  4th dimension coaster
# 12     919055  03-Oct-2008    CA                 Spider
# 13     919115  02-Oct-2008    CA       motion simulator
# 14     919196  30-Sep-2008    CA  4th dimension coaster
# 15     919057  26-Sep-2008    CA           bumper boats
# 16     919074  25-Sep-2008    CA             drop tower
# 17     919127  25-Sep-2008    CA         wooden coaster
# 18     919096  20-Sep-2008    CA  steel sitdown coaster
# 19     919097  20-Sep-2008    CA  steel sitdown coaster
# 20     919076  19-Sep-2008    CA            bumper cars
# 21     919128  19-Sep-2008    CA               Top Spin
# 22     919126  17-Sep-2008    CA         wooden coaster
# 23     919081  13-Sep-2008    CA              dark ride
# 24     919056  12-Sep-2008    CA              airplanes
# 25     919102  11-Sep-2008    CA              boat ride
# 26     919092  08-Sep-2008    CA               carousel
# 27     919106  07-Sep-2008    CA  steel sitdown coaster
# 28     919110  06-Sep-2008    CA  steel sitdown coaster
# 29     919089  05-Sep-2008    CA              boat ride
# ...       ...          ...   ...                    ...
# 14891  898697  13-Jul-1988    TX          Auto Skooters
# 14892  898696  06-Jul-1988    TX             flume ride
# 14893  898695  22-Jun-1988    TX           ferris wheel
# 14894  898694  20-Jun-1988    TX        shoot the chute
# 14895  898693  18-Jun-1988    TX        shoot the chute
# 14896  898692  18-Jun-1988    TX            bumper cars
# 14897  898691  11-Jun-1988    TX   shuttle loop coaster
# 14898  898690  09-Jun-1988    TX            bumper cars
# 14899  898687  02-Jun-1988    TX        shoot the chute
# 14900  898688  02-Jun-1988    TX        shoot the chute
# 14901  898689  02-Jun-1988    TX        shoot the chute
# 14902  898685  25-May-1988    TX             flume ride
# 14903  898686  25-May-1988    TX             flume ride
# 14904  898684  21-May-1988    TX  steel sitdown coaster
# 14905  898683  06-May-1988    TX  steel sitdown coaster
# 14906  898682  27-Apr-1988    TX                  train
# 14907  898664  22-Apr-1988    TX        shoot the chute
# 14908  898663  15-Apr-1988    TX  steel sitdown coaster
# 14909  898662  02-Apr-1988    TX           unidentified
# 14910  898661  01-Apr-1988    TX             drop tower
# 14911  898660  26-Mar-1988    TX        shoot the chute
# 14912  898659  11-Mar-1988    TX               Himalaya
# 14913  898658  11-Mar-1988    TX                  combo
# 14914  898657  05-Mar-1988    TX              Sky Diver
# 14915  898652  26-Feb-1988    TX                  train
# 14916  898651  19-Feb-1988    TX            helicopters
# 14917  898649  10-Jan-1988    TX                  train
# 14918  898650  10-Jan-1988    TX                  train
# 14919  898648  18-Apr-1987    TX                    Z64
# 14920  898647  02-Jan-1986    TX                go kart
#
#                    Device type                   Manufacturer  \
# 0           Flying carpet ride        Wisdom Industries, Ltd.
# 1      Coaster - miscellaneous                         Vekoma
# 2           Spinning cups/tubs                            NaN
# 3           Spinning cups/tubs                            NaN
# 4                     Carousel                         Morgan
# 5      Coaster - miscellaneous                     Intamin AG
# 6                   Track ride            Walt Disney Company
# 7             Coaster - wooden           Custom Coasters Int.
# 8         Plane/jet/helicopter                            NaN
# 9                   Flume ride                 Arrow Dynamics
# 10            Coaster - wooden                         Morgan
# 11     Coaster - 4th dimension                 Arrow Dynamics
# 12       Orbiter/octopus/remix            Eyerly Aircraft Co.
# 13                   Simulator                            NaN
# 14     Coaster - 4th dimension                 Arrow Dynamics
# 15                 Bumper boat          J & J Amusements, Inc
# 16                  Drop tower                S & S Power Inc
# 17            Coaster - wooden           Custom Coasters Int.
# 18     Coaster - miscellaneous                            NaN
# 19     Coaster - miscellaneous                            NaN
# 20                  Bumper car   Majestic Manufacturing, Inc.
# 21           Flipping platform                     Huss Rides
# 22            Coaster - wooden           Custom Coasters Int.
# 23                  Track ride                            NaN
# 24        Plane/jet/helicopter                       Zamperla
# 25                   Boat ride                 Arrow Dynamics
# 26                    Carousel                            NaN
# 27     Coaster - miscellaneous                            NaN
# 28     Coaster - miscellaneous                            NaN
# 29                   Boat ride                            NaN
# ...                        ...                            ...
# 14891               Bumper car                   Export Sales
# 14892               Flume ride  O.D. Hopkins Associates, Inc.
# 14893     Ferris/gondola wheel                 Eli Bridge Co.
# 14894          Shoot the chute                 Arrow Dynamics
# 14895          Shoot the chute                 Arrow Dynamics
# 14896               Bumper car                          Lusse
# 14897  Coaster - miscellaneous                     Intamin AG
# 14898               Bumper car                          Lusse
# 14899          Shoot the chute                 Arrow Dynamics
# 14900          Shoot the chute                 Arrow Dynamics
# 14901          Shoot the chute                 Arrow Dynamics
# 14902               Flume ride  O.D. Hopkins Associates, Inc.
# 14903               Flume ride  O.D. Hopkins Associates, Inc.
# 14904  Coaster - miscellaneous             Schwarzkopf  Rides
# 14905  Coaster - miscellaneous             Schwarzkopf  Rides
# 14906                    Train     Chance Manufacturing, Inc.
# 14907          Shoot the chute                 Arrow Dynamics
# 14908  Coaster - miscellaneous             Schwarzkopf  Rides
# 14909                  Unknown                Thomas Brothers
# 14910               Drop tower                     Intamin AG
# 14911          Shoot the chute                 Arrow Dynamics
# 14912            Himalaya-type                      Reverchon
# 14913               Roundabout    Hampton Amusement Rides LLC
# 14914    Wheel w/spinning cars     Chance Manufacturing, Inc.
# 14915                    Train     Chance Manufacturing, Inc.
# 14916     Plane/jet/helicopter        Allan Herschell Company
# 14917                    Train     Chance Manufacturing, Inc.
# 14918                    Train     Chance Manufacturing, Inc.
# 14919         Coaster - zyklon                        Pinfari
# 14920                  Go-kart                           Soli
#
#                                        Category   Age  \
# 0                       Ejection/fall from ride  17.0
# 1                     Unknown (not enough info)  19.0
# 2              Illness or neurological symptoms  51.0
# 3              Illness or neurological symptoms  38.0
# 4                     Entrapment or pinch-point  33.0
# 5                     Body pain (normal motion)  40.0
# 6                     Body pain (normal motion)  77.0
# 7                     Body pain (normal motion)  21.0
# 8                      Injured in queue or exit  35.0
# 9                Load/Unload: scrape or stumble  38.0
# 10                    Body pain (normal motion)  24.0
# 11                    Body pain (normal motion)  37.0
# 12                    Body pain (normal motion)  41.0
# 13                    Body pain (normal motion)  41.0
# 14                    Unknown (not enough info)  25.0
# 15             Vehicle moved during load/unload  77.0
# 16     Patron hit something within ride vehicle  42.0
# 17                    Body pain (normal motion)  23.0
# 18                    Entrapment or pinch-point  20.0
# 19               Load/Unload: scrape or stumble  28.0
# 20                     Injured in queue or exit  64.0
# 21     Patron hit something within ride vehicle  10.0
# 22     Patron hit something within ride vehicle  55.0
# 23                               Seizure or LOC  24.0
# 24               Load/Unload: scrape or stumble   NaN
# 25             Illness or neurological symptoms  49.0
# 26              Fell from seat, but not carrier  37.0
# 27             Illness or neurological symptoms  39.0
# 28             Illness or neurological symptoms  42.0
# 29             Illness or neurological symptoms  20.0
# ...                                         ...   ...
# 14891  Patron hit something within ride vehicle   NaN
# 14892  Patron hit something within ride vehicle   NaN
# 14893  Patron hit something within ride vehicle   NaN
# 14894                 Body pain (normal motion)   NaN
# 14895                 Body pain (normal motion)   NaN
# 14896                 Unknown (not enough info)   NaN
# 14897                 Body pain (normal motion)   NaN
# 14898                 Unknown (not enough info)   NaN
# 14899                 Body pain (normal motion)   NaN
# 14900  Patron hit something within ride vehicle   NaN
# 14901  Patron hit something within ride vehicle   NaN
# 14902  Patron hit something within ride vehicle   NaN
# 14903  Patron hit something within ride vehicle   NaN
# 14904                 Body pain (normal motion)   NaN
# 14905  Patron hit something within ride vehicle   NaN
# 14906            Load/Unload: scrape or stumble   NaN
# 14907                         Equipment failure   NaN
# 14908                 Body pain (normal motion)   NaN
# 14909  Patron hit something within ride vehicle   NaN
# 14910                 Unknown (not enough info)   NaN
# 14911                 Injured by foreign object   NaN
# 14912                 Unknown (not enough info)   NaN
# 14913                 Unknown (not enough info)   NaN
# 14914  Load/Unload: hit or pinched by restraint   NaN
# 14915                                Derailment   NaN
# 14916                 Unknown (not enough info)   NaN
# 14917            Load/Unload: scrape or stumble   NaN
# 14918            Load/Unload: scrape or stumble   NaN
# 14919                   Ejection/fall from ride  15.0
# 14920     Collision: patron-controlled vehicles  30.0
#
#                                     Accident Description  \
# 0      17-yo female was ejected from the ride mid-cyl...
# 1                 Guest injured right hand while riding.
# 2      Guest stated when she sat down in the vehicle,...
# 3      Guest stated she felt lightheaded and experien...
# 4      Guest was standing next to her child who was r...
# 5      Guest complained of chest pain prior and after...
# 6      Guest complained of chest pain prior to and af...
# 7                    Patron complained of low back pain.
# 8      Guest stated she fainted prior to loading.  Sh...
# 9                       Left knee pain when exiting log.
# 10     While riding, patron felt a pop in her hip and...
# 11     Guest came to first aid complaining of stomach...
# 12     While riding, the patron slid down his seat an...
# 13     Guest stated he felt back pain as he stood up ...
# 14     Park received a request to pay medical expense...
# 15     Guest was exiting the boat, which had not yet ...
# 16     Guest stated her left shoulder hit the restrai...
# 17                 Patron states neck pain after riding.
# 18     Guest stated that her foot got caught exiting ...
# 19     Guest stated she cut her left heel when boardi...
# 20     Guest stated she was exiting the ride platform...
# 21                        Patron hit teeth on restraint.
# 22                          Patron hit left side on car.
# 23     Guest stated she had a seizure while riding. H...
# 24     Adult patron tripped and fell out of airplane,...
# 25     Guest complained of difficulty breathing after...
# 26     Guest stated she injured her right wrist after...
# 27     Guest stated she had neck and shoulder pain an...
# 28     Guest stated she experienced nausea, weakness,...
# 29     Guest states she had increase of twitching aft...
# ...                                                  ...
# 14891                                  Knocked out tooth
# 14892                                  Knocked out tooth
# 14893                          Injury to right shoulder.
# 14894                                               Pain
# 14895                                               Pain
# 14896                                             Strain
# 14897                                             Strain
# 14898                                           Fracture
# 14899                                             Sprain
# 14900                              Hit mouth on lap bar.
# 14901                              Hit mouth on lap bar.
# 14902                                             Bruise
# 14903                                             Bruise
# 14904                                             Strain
# 14905                                         Laceration
# 14906                    Mother tripped & fell on child.
# 14907  18 patrons injured in accident.  Type/cause of...
# 14908                                             Strain
# 14909                     Sliding sideways in rear seat.
# 14910                                          Contusion
# 14911                                      Hit by water.
# 14912                                            Scratch
# 14913                                               Bump
# 14914                         Pinched hand recd blister.
# 14915                                  Train derailment.
# 14916                                           Swelling
# 14917                    Fell while getting out of ride.
# 14918                        Tripped while exiting ride.
# 14919  Jumped into the roller coaster car as the ride...
# 14920             Go kart hit from behind while stopped.
#
#                                                   Injury
# 0                  Multiple broken ribs and bruised lung
# 1              Injured hand.  Treated at local hospital.
# 2                 Nosebleed.  Treated at local hospital.
# 3      Dizziness, high blood pressure.  Treated at lo...
# 4                                      injured left foot
# 5                                             Chest pain
# 6                Chest pain.  Treated at local hospital.
# 7                 Back pain.  Treated at local hospital.
# 8                   Fainted.  Treated at local hospital.
# 9         Pain in left knee.  Treated at local hospital.
# 10     Hip pain.  Transported to the hospital as a pr...
# 11                   Stomach pain.  Treated at hospital.
# 12     Back pain.  Transported to hospital by ambulance.
# 13                Back pain.  Treated at local hospital.
# 14                                  Treated at hospital.
# 15                        Patron transported to hospital
# 16           Shoulder injury. Treated at local hospital.
# 17                                            Neck pain.
# 18              Foot injury.  Treated at local hospital.
# 19              Foot injury.  Treated at local hospital.
# 20                             Treated at local hospital
# 21                     Loose tooth.  Treated by dentist.
# 22                                Pain to left rib area.
# 23                  Seizure.  Treated at local hospital.
# 24                                 Possible broken wrist
# 25     Breathing difficulty.  Treated at local hospital.
# 26          Injury to wrist.  Treated at local hospital.
# 27     Neck/shoulder pain, numbness in extremities.  ...
# 28     Dizziness, nausea, disorientation.  Treated at...
# 29     Exacerbation of twitching.  Treated at local h...
# ...                                                  ...
# 14891                                  Knocked out tooth
# 14892                                  Knocked out tooth
# 14893                                             Bruise
# 14894                                               Pain
# 14895                                               Pain
# 14896                                             Strain
# 14897                                             Strain
# 14898                                           Fracture
# 14899                                             Sprain
# 14900                                           Loosened
# 14901                                           Loosened
# 14902                                             Bruise
# 14903                                             Bruise
# 14904                                             Strain
# 14905                                         Laceration
# 14906                                               Bump
# 14907  Park reported injuries as 'pain, stiffness, st...
# 14908                                             Strain
# 14909                                            Cracked
# 14910                                          Contusion
# 14911                                               Pain
# 14912                                            Scratch
# 14913                                               Bump
# 14914                                            Blister
# 14915  Five patrons suffered injuries, including thre...
# 14916                                           Swelling
# 14917                                          Contusion
# 14918                                             Strain
# 14919                                              Fatal
# 14920                                               Pain
#
# [14921 rows x 10 columns]

# %%
saferparks_grouped = saferparks.groupby('Category')
saferparks_grouped.mean()
# Out:
#                                                                ID        Age
# Category
# Abrupt stop/drop/lurch                              910206.261261  25.656250
# Body pain (normal motion)                           909195.971188  24.527864
# Burn (includes friction burn)                       907840.235955  14.893333
# Choking, water inhalation, suffocation              908886.321429  11.761905
# Collision: operator-controlled vehicles             908489.068493  21.877193
# Collision: patron-controlled vehicles               907109.472527  18.642185
# Derailment                                          911969.304348  21.250000
# Ejection/fall from ride                             908824.821429  12.519651
# Electrical shock                                    905219.566667  12.263158
# Employee injured                                    910935.952381  26.695652
# Entrapment or pinch-point                           910573.695473  16.643836
# Environmental issue                                 908562.400000  21.200000
# Equipment failure                                   910667.929688  17.739583
# Extremity hit something outside carrier             909130.736842  15.400000
# Fall (climb or play area)                           908965.910326  13.774603
# Fell from seat, but not carrier                     911059.134615  10.645833
# Fell or slid out of waterslide or snowtube          913221.549296  23.828125
# Go-kart crashed (no further description)            908756.357143  14.166667
# Go-kart or bumper car hit stationary object         906597.123853  15.567976
# Hyperextension or dislocation                       910570.564103  27.423358
# Illness or neurological symptoms                    915180.656471  39.855746
# Injured by foreign object                           909292.427907  21.265896
# Injured in queue or exit                            909844.280899  15.976378
# Load/Unload: hit or pinched by restraint            909823.814488  15.455253
# Load/Unload: scrape or stumble                      910781.846769  22.553270
# Other                                               911624.210526  16.923077
# Patron flipped off inner tube or mat                909299.763473  24.941374
# Patron hit by ride                                  908417.447368  22.515152
# Patron hit something within ride vehicle            908811.255965  17.164395
# Patron's body hit something (participatory attr...  908655.774081  20.886772
# Patrons collided                                    908368.448029  21.535714
# Patrons collided within vehicle                     909534.327273  16.158416
# Restraint too tight                                 909841.882353  22.050000
# Seatbelt abrasion or bruising                       905011.078431  11.809524
# Seizure or LOC                                      914202.018293  27.233766
# Unknown (not enough info)                           913240.837349  21.833333
# Unscheduled stop                                    911563.990991  23.926829
# Vaginal or rectal bleeding                          913306.933333  18.230769
# Vehicle moved during load/unload                    911367.148515  28.746988

# %%
saferparks['Device type'] = saferparks['Device type'].replace({
        # alphabatized by new Value var
        'Bumper boat': 'Boat ride', 
        'Bumper car' : 'Car ride',
        'Bungee' : 'Gravity drop ride',
        'Carousel' : 'Car ride',
        'Claw-type' : 'Spinning type ride',
        'Climbing wall' : 'Play strucutre',
        'Coaster - miscellaneous' : 'Coaster',
        'Coaster - wooden' : 'Coaster',
        'Coaster - 4th dimension' : 'Coaster',
        'Coaster - inverted' : 'Coaster',
        'Coaster - wild mouse' : 'Coaster',
        'Coaster - family/kiddie' : 'Coaster',
        'Coaster - zyklon' : 'Coaster',
        'Coaster - bobsled' : 'Coaster',
        'Coaster - flying' : 'Coaster',
        'Coaster - stand-up' : 'Coaster',
        'Coaster - suspended' : 'Coaster',
        'Coaster - pipeline' :'Coaster',
        'Coaster - mine train' : 'Coaster',
        
        'Drop tower' : 'Gravity drop ride',
        'Enterprise' : 'Spinning type ride',
        
        'Ferris/gondola wheel' : 'Flipping platform',
        'Flume ride' : 'Water ride',
        'Flying carpet ride' : 'Flipping platform',
        'Fun house' : 'Play strucure',
        
        'Giant swing' : 'Gravity drop ride',
        'Go-kart' : 'Car ride',
        
        'Hanglider ride' : 'Gravity drop ride',
        'Himalaya-type' : 'Spinning type ride',
        'Hurricane-type': 'Spinning type ride',
        
        'Inflatable bouncer': 'Inflatable',
        'Inflatable climb wall' : 'Inflatable',
        'Inflatable - misc.' : 'Inflatable', #check with team,
        'Inflatable slide' : 'Inflatable',
        'Inverter' : 'Flipping platform',
        
        'Lazy river' : 'Boat ride',
        'Looper' : 'Flipping platform',
        
        'Non-motorized spinners' : 'Flipping platform',
        
        'Monorail' : 'Safe ride',
        
        'Obstacle course' : 'Play structure',
        'Orbiter/octopus/remix' : 'Flipping platform',
        
        'Paratrooper-type' : 'Flipping platform',
        'Plane/jet/helicopter': 'Car ride',
        'Pirate ship' : 'Gravity drop ride',
        
        'Rafting ride' : 'Boat ride',
        'Ranger/kamikaze' : 'Flipping platform',
        'Robotic ride' : 'Coaster',
        'Roll-o-plane/booster/speed' : 'Flipping platform',
        'Rotor/gravitron' : 'Spinning type ride',
        'Roundabout' : 'Safe ride',
        
        'Simulator' : 'Car ride',
        'Sizzler/scrambler' : 'Spinning type ride',
        'Sky cycle' : 'Car ride',
        'Sky ride/ski lift': 'Car ride',
        'Slide' : 'Slide ride',
        'Shoot the chute' : 'Slide ride',
        'Snow tube/toboggan' : 'Slide ride',
        'Spinning cups/tubs' : 'Spinning type ride',
        'Spinning tower ride' : 'Spinning type ride',
        'Spinning pendulum' : 'Spinning type ride',
        'Spinning ride - misc.' : 'Spinning type ride',
        'Spinning track ride' : 'Spinning type ride',
        'Skydiving ride' : 'Gravity drop ride',
        'Swing ride' : 'Spinnin ride',
        
        'Tilt-a-whirl/waltzer': 'Spinning type ride',
        'Track ride' : 'Car ride',
        'Train' : 'Safe ride',
        'Trabant' : 'Spinning ride',
        'Tram/trolley' : 'Safe ride',
        'Tornado-type' : 'Spinning ride',

        'Water ski tow' : 'Car ride',
        'Water slide' : 'Slide ride',
        'Wave pool' : 'Play structure',
        'Wet Play' : 'Play structure',
        'Wheel w/spinning cars' : 'Car ride',
        'Whip' : 'Car ride'         
        })

saferparks['Category'] = saferparks['Category'].replace({
        
        'Collision: operator-controlled vehicles': 'Collision',
        'Collision: patron-controlled vehicles': 'Collision',
        
        'Derailment' : 'Equipment failure',
        
        'Extremity hit something outside carrier': 'Patron collided with object/other patron',
        
        'Go-kart crashed (no further description)' : 'Go-kart crash',
        'Go-kart or bumper car hit stationary object' : 'Go-kart crash',
       
        
        'Load/Unload: hit or pinched by restraint': 'Injury during loading/unloading',
        'Load/Unload: scrape or stumble': 'Injury during loading/unloading',
        
        'Other': 'Other/Unknown',
        
        'Patron flipped off inner tube or mat' : 'Fell or slid out of waterslide or snowtube', 
        'Patron hit by ride': 'Patron hit',
        'Patron hit something within ride vehicle': 'Patron hit',
        
        'Restraint too tight' : 'Load/Unload: hit or pinched by restraint',
        
        'Seatbelt abrasion or bruising' : 'Load/Unload: hit or pinched by restraint',
        
        'Unknown (not enough info)': 'Other/Unknown'
        
        })


saferparks.to_csv('./Resources/Cleaned_Saferparks.csv', sep = '\t', index = False)
